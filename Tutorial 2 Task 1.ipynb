# %%
variable1 = 'Vijaya Yeruva'
variable2 = ['Python','Machine Learning', 'Deep Learning']
variable3 = (4,9,16,25)
variable4 = [2.0,3.0,5.0,7.0,11.0]
variable5 = {'key1': 65537, 'key2': 1729, 'key3': 1806}
variable6 = {'key1': 3.1415, 'key2': 2.68545, 'key3': 1.61803}
variable7 = {1:'Jamie', 2:'Jack', 3:'Joey'}
variable8 = {1:['jamie','Jack','Joey'], 2:['Deo', 'Katie', 'Lauren'],
            3:['Mustafa','Luke','M']}

# %%
len(variable5)
# Out:
# 3

# %%
str1 = 1
str2 = "bye"

print(str1 + str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19248\2147073190.py in <module>
#       2 str2 = "bye"
#       3
# ----> 4 print(str1 + str2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list1 = [1,2]
list2 = [3,4]

print(list1 + list2)
# Out:
# [1, 2, 3, 4]

# %%
print (2 <= 3)
# Out:
# True
